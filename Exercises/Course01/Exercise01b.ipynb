# %% [markdown]
# # Horizon Loading Exercise

# %% [markdown]
# ***

# %% [markdown]
# ## <span style="color:blue">Create 3-D View from ASCII File</span>
#
# Befriko Murdianto, Apr 2025<br>
# Reservoir Geophysics Graduate Program<br>
# University of Indonesia

# %% [markdown]
# ***

# %%
import numpy as np

# Load the ASCII file
#from google.colab import drive
#drive.mount('/content/drive', force_remount=True)
#data = np.loadtxt('/content/drive/My Drive/Caddo.txt');
data = np.loadtxt('C:/Users/befriko.murdianto/OneDrive/Desktop/Documents/UI Lecture/2024/Fall Term/CompGeo-UI-main/Data/Caddo.txt')

# Select the desired column (e.g., the first, second and fifth column)
x = data[:, 0]; y = data[:, 1]; z = data[:, 4]

# %%
xmin = int(np.min(x)); xmax = int(np.max(x))
ymin = int(np.min(y)); ymax = int(np.max(y))
nxline = (xmax-xmin)+1; niline = (ymax-ymin)+1
reshape_z = np.reshape(z, (niline,nxline))
xline = np.linspace(xmin, xmax, nxline); iline = np.linspace(ymin, ymax, niline)
x, y = np.meshgrid(xline, iline)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Display plan view
plt.imshow(reshape_z, extent=[xmin, xmax, ymax, ymin], cmap='hsv', aspect='auto', origin='upper')
plt.title('Caddo: Plan View')
plt.xlabel('Crossline')
plt.ylabel('Inline')
plt.colorbar()
plt.show()

# %%
# Create a figure and a 3D Axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
surf = ax.plot_surface(x, y, reshape_z, cmap='hsv')
ax.set_zlim(np.max(reshape_z), np.min(reshape_z))
ax.set_xlabel(r'Crossline')
ax.set_ylabel(r'Inline')

# Add a color bar which maps values to colors
fig.colorbar(surf)
fig.suptitle('Caddo: 3-D View')

# Show the plot
plt.show()
